# %% [markdown]
# <a href="https://colab.research.google.com/github/mayuri-lalwani/RL---CMPE260-Final-Project/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Testing

# %%
! git clone https://github.com/mayuri-lalwani/RL---CMPE260-Final-Project.git

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /RL---CMPE260-Final-Project

# %%
# !wget "https://drive.google.com/uc?export=download&id=1-7dVdjCIZIxh8hHJnGTK-RA1-jL1tor4" -O renderer.pkl

# %%
# !wget "https://drive.google.com/uc?export=download&id=1a3vpKgjCVXHON4P7wodqhCgCMPgg1KeR" -O actor.pkl

# %%
# !python3 baseline/test.py --max_step=80 --actor=actor.pkl --renderer=renderer.pkl --img=image/JayChou.png --divide=5
# Out:
# mkdir: cannot create directory ‘output’: File exists
# canvas step 0, L2Loss = 0.027837784960865974
# canvas step 1, L2Loss = 0.020823081955313683
# canvas step 2, L2Loss = 0.017510464414954185
# canvas step 3, L2Loss = 0.014736935496330261
# canvas step 4, L2Loss = 0.013086788356304169
# canvas step 5, L2Loss = 0.011480090208351612
# canvas step 6, L2Loss = 0.010128184221684933
# canvas step 7, L2Loss = 0.009193360805511475
# canvas step 8, L2Loss = 0.008043474517762661
# canvas step 9, L2Loss = 0.007643299642950296
# canvas step 10, L2Loss = 0.007205150555819273
# canvas step 11, L2Loss = 0.006861391011625528
# canvas step 12, L2Loss = 0.006569705903530121
# canvas step 13, L2Loss = 0.0062294211238622665
# canvas step 14, L2Loss = 0.00597179913893342
# canvas step 15, L2Loss = 0.00589756527915597
# canvas step 16, L2Loss = 0.005770936608314514
# canvas step 17, L2Loss = 0.005620225798338652
# canvas step 18, L2Loss = 0.005506236106157303
# ...

# %%
# !ffmpeg -r 30 -f image2 -i output/generated%d.png -s 512x512 -c:v libx264 -pix_fmt yuv420p video.mp4 -q:v 0 -q:a 0
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
from IPython.display import display, Image
import moviepy.editor as mpy
display(mpy.ipython_display('video.mp4', height=256, max_duration=100.))
display(Image('output/generated399.png'))
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.
# <div align=middle><video height='256' max_duration='100.0'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
